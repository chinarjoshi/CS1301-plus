# %%
# ATTENDANCE FORM
from IPython import display
display.Image("/home/c/notes/plus/attendance.png", width=400, height=400)

# %% [markdown]
# ## ^ Please do attendance, I want to get paid

# %% [markdown]
# ### Topic List
# * Basics
#     - Variable naming rules
#     - Data types and conversions
#     - Order of operations
#     - Import statement
#     - Math operators on different types
# * Functions
#     - Writing a function header
#     - Referencing arguments
#     - Printing vs returning
#     - Calling functions
# * Conditionals
#     - Boolean expressions
#     - 'if' statement syntax
#     - 'in' operator as Boolean
# * Loops
#     - 'for' and 'while' loop syntax
#     - Range function
#     - 'in' operator with for loop
#     - Rewriting for and while loops
#     - break and continue
# * Strings
#     - Indexing
#     - Slicing
#     - Methods

# %% [markdown]
# ## *Opener*
# ### Analyze the topic list
#
# Get in groups of 4 on whiteboards, assign a number 1-4 for each person, and write your number on what topics you want to review
#
# Then talk about everything you can remember about each bullet. Circle topics you're all unsure of so you can get more help.

# %% [markdown]
# ## *Main Activity*

# %% [markdown]
# #### Section 0: Basics

# %% [markdown]
# Expression |	Value	| Data Type |
# | ------- | -------- | --------|
# 2 + 3		|         |
# 2.0 + 1		| |
# '2' + '3'		| |
# 2 + 3.0
# 2 * '3'
# bool(str(0))
# 2 / 4
# 7 // 4
# 7 % 4
# 2 ** 3
# '2' * 3
# 4 * True

# %% [markdown]
# #### Section 1: Logic and conditionals
#
# Write the values of p, q, and r that satisfy the following Boolean expressions.
#
# Hint: Write a truth table like the following

# %% [markdown]
# | p      | q | p and q |
# | ----------- | ----------- | ---- |
# | True      | True       | _ |
# | True   | False        | _ |
# | False   | True        | _ |
# | False   | False        | _ |

# %% [markdown]
# (p and not q) or (not p and q)
#
# (p != q) == (r != q)
#
# (p and (q != r)) or (not p and (q == r))
#
# (p and (q != r)) or (not p and (q == r))
#
# (p == (q and r)) != (not p == (not q or not r))

# %% [markdown]
# #### Section 2:

# %% [markdown]
# #### Section 3: Coding problems
#
# On your whiteboards, HAND WRITE a solution to the following coding problems. Try to distribute the work evenly and consider the most important information from the prompt.

# %% [markdown]
# #### CODING PROBLEM #1
# Write a function named factorial that takes in a positive integer as input and returns its factorial. The function should have 1 argument and return an integer.
#
# Examples:
#
#     >>> factorial(5)
#     120
#     >>> factorial(7)
#     5040
#     >>> factorial(3)
#     6

# %% [markdown]
# #### CODING PROBLEM #2
#
# Write a function named is_prime that takes in a positive integer as input and returns a Boolean indicating if the number is prime. The function should have 1 argument and return a Boolean.
#
# Examples:
#
#     >>> is_prime(7)
#     True
#     >>> is_prime(12)
#     False
#     >>> is_prime(17)
#     True

# %% [markdown]
# #### CODING PROBLEM #3
#
# Write a function named shortest_distance that takes in two points represented by their x and y coordinates and returns the Euclidean distance between them. The function should have 4 arguments (2 for each point) and return a float.
#
# Examples:
#
#     >>> shortest_distance(0, 0, 3, 4)
#     5.0
#     >>> shortest_distance(1, 2, 4, 6)
#     5.0
#     >>> shortest_distance(3, 2, -1, -2)
#     5.0

# %% [markdown]
# #### CODING PROBLEM #4
#
# Write a function named sort that takes in a string as input and returns a string with the characters sorted in alphabetical order. The function should have 1 argument and return a string. Try to find both the easy and hard way of doing it.
#
# Examples:
#
#     >>> sort('hello')
#     'ehllo'
#     >>> sort('python')
#     'hnopty'
#     >>> sort('mississippi')
#     'iiiimpssss'

# %% [markdown]
# #### CODING PROBLEM #5
#
# Write a function named reverse_num that takes a positive integer as input and returns its reverse. The reverse of a positive integer is the number obtained by reading its digits from right to left.
#
#     >>> reverse_num(12345)
#     54321
#     >>> reverse_num(0)
#     0
#     >>> reverse_num(12)
#     21

# %% [markdown]
# #### CODING PROBLEM #6
#
# Write a function named gcd that takes in 2 positive integers as input and returns the greatest common divisor of the two numbers. The function should have 2 arguments and return an integer.
#
#     >>> gcd(54, 24)
#     6
#     >>> gcd(7, 13)
#     1
#     >>> gcd(16, 8)
#     8

# %% [markdown]
# #### CODING PROBLEM #7
#
# Write a function closest_zero_sum that takes in a list of integers and returns a pair of integers that have the closest sum to zero. If there are multiple pairs with the same closest sum, return the pair with the smallest absolute values.
#
# Examples:
#
#     >>> closest_zero_sum([-1, 2, 3, -4])
#     (-1, 2)
#     >>> closest_zero_sum([-1, -2, -3, 4, 5, -4])
#     (-1, 1)
#     >>> closest_zero_sum([1, 2, 3, -2])
#     (2, -2)
